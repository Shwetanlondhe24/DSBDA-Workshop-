# %%
bool([])
# Out:
# False

# %%
a=['a','b',"c","d"]
for i in a:
  a.append(i.upper())
print(a)
#runtime error

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %%
s="abcdefghijk"
s[-1:-6:-1] #[start,stop,step]
# s[20] - index of out of range
# s[2000:50] - no error, we will get empty string. slice opertion dont give error (:)
# when we move in opp direction empty string - s[-2:-8] = by default step 1 so in opp direction
# Out:
# 'kjihg'

# %%
# lambda expression - anonymous function/one line function
# usage- code optimization
s=lambda sd:sd*2
s(4)
# Out:
# 8

# %%
e=lambda even:even%2==0
data =[1,2,3,4,5,6,7,8]
list(map(e,data)) # [false,true]
list(filter(e,data))
# Out:
# [2, 4, 6, 8]

# %%
seq=['soup','dog','salad']
list(map(lambda x:x[0]=='s',seq))
# Out:
# [True, False, True]

# %%
seq=['soup','dog','salad']
list(filter(lambda x:x[0]=='s',seq))
# Out:
# ['soup', 'salad']

# %%
def demo(speed,bday):
  if bday =="false":
    if speed<=60:
      print("no ticket")
    if (61<=speed<=80):
      print("small ticket")
    if (speed>=81):
      print("big ticket")

  if bday=="true":
    if speed<=65:
      print("no ticket")
    if (66<=speed<=84):
      print("small ticket")
    if (speed>=86):
      print("big ticket")

demo(61,"false")
# Out:
# small ticket

# %%
num1=int(input("enter a num: "))

def reverse(num1):
  for
#reverse(num2) i in num1:
    num2=num1%10
    num1//10
  print(num2)
# Out:
# enter a num: 12

# %%
n1=int(input("enter a num: "))
n2=int(input("enter a sec num: "))

def palindrome(n1):

  temp=n1+n2
  ch=str(temp)

  #wrong

# %%
n1=input("enter the number: ")
n2=int(n1[::-1])
n3=str(int(n1)+n2)
while n3!=n3[::-1]:
  print("num is: ", n3)

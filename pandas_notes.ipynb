# %%
import pandas as pd
import numpy as np

# %%
d1=[1,2,3,4,5]
d2=["a","b","c","d","e"]
d3=(100,101,103,109,131)
d4={"p":1001,"s":1002,"d":898,"e":989,"f":732}

# %%
pd.Series(d2)
# series is a 1d numpy array
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
pd.Series(d2,d2) # (data, index)
# Out:
# a    a
# b    b
# c    c
# d    d
# e    e
# dtype: object

# %%
type(d4)
# Out:
# dict

# %%
pd.Series(d4,d1)
# Out:
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# dtype: float64

# %%
pd.Series(d1,d4)
# Out:
# p    1
# s    2
# d    3
# e    4
# f    5
# dtype: int64

# %%
ser1=pd.Series([1,2,3],["a","b","c"])
ser2=pd.Series([1,2,3],["a","e","c"])
print(ser1+ser2)
# Out:
# a    2.0
# b    NaN
# c    6.0
# e    NaN
# dtype: float64

# %%
df=pd.DataFrame(np.random.rand(5,4), ["a","b","c","d",'e'],["s","f","g","h"]) # (data,index,col_name)
df
# Out:
#           s         f         g         h
# a  0.770730  0.822173  0.441513  0.810764
# b  0.973000  0.378840  0.887121  0.319059
# c  0.152119  0.059593  0.828038  0.709390
# d  0.288934  0.843502  0.112087  0.556016
# e  0.938576  0.660106  0.659902  0.948271

# %%
type(df['s']) # sindgle col type is series
# Out:
# pandas.core.series.Series

# %%
df["a"]>3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-b208654640fc> in <cell line: 0>()
# ----> 1 df["a"]>3
#
# ...

# %%
df["s"]>2
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# Name: s, dtype: bool

# %%
df.loc["e"] # fetch rows
# Out:
# s    0.938576
# f    0.660106
# g    0.659902
# h    0.948271
# Name: e, dtype: float64

# %%
df.iloc[4] # fetch rows using index
# Out:
# s    0.938576
# f    0.660106
# g    0.659902
# h    0.948271
# Name: e, dtype: float64

# %%
df[3:3]
# Out:
# Empty DataFrame
# Columns: [s, f, g, h]
# Index: []

# %%
df.loc["d","g"]
# Out:
# np.float64(0.11208659883183303)

# %%
df["f+g"]=df["f"]+df["g"]
df.columns
# Out:
# Index(['s', 'f', 'g', 'h', 'f+g'], dtype='object')

# %%
# axes =0 rows (by default)
# axes=1 col
df=df.drop("f+g", axis=1) # or df.drop("f+g", axis=1, inplace=True)

# %%
df["food"]=["samosa","cake","manchurian","ice cream","kachori"]
df
# Out:
#           s         f         g         h        food
# a  0.770730  0.822173  0.441513  0.810764      samosa
# b  0.973000  0.378840  0.887121  0.319059        cake
# c  0.152119  0.059593  0.828038  0.709390  manchurian
# d  0.288934  0.843502  0.112087  0.556016   ice cream
# e  0.938576  0.660106  0.659902  0.948271     kachori

# %%
df
# Out:
# ['samosa', 'cake', 'manchurian', 'ice cream', 'kachori']

# %%
df1=pd.read_csv("/content/example")

# %%
df2=pd.read_excel("/content/Excel_Sample.xlsx")

# %%
df1.to_csv("exported data") # to export

# %%
df3=pd.read_html("https://www.fdic.gov/bank-failures/failed-bank-list")

# %%
type(df3) # df is possible inside list
# Out:
# list

# %%
demo=(9) # tuple declaration but its int
type(demo)
# Out:
# int

# %%
demo2=(9,) # tuple with one element
type(demo2)
# Out:
# tuple

# %%
demo3={}
type(demo3)
# Out:
# dict
